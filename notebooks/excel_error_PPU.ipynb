# %%
import pandas as pd

# %%
df = pd.read_excel("data/error_record_2022.xlsx")
# Out:
# C:\Users\robfr\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
df.head()
# Out:
#    Unnamed: 0 Unnamed: 1           Unnamed: 2       Unnamed: 3 Unnamed: 4  \
# 0         NaN        NaN         Error Record              NaN        NaN
# 1         NaN        NaN  2022-01-01 00:00:00              NaN        NaN
# 2         NaN        NaN                  NaN              NaN        NaN
# 3         NaN       Date      Production Area  Licensed Status    Product
# 4         NaN        NaN                  NaN              NaN        NaN
#
#           Unnamed: 5               Unnamed: 6        Unnamed: 7  \
# 0                NaN                      NaN               NaN
# 1                NaN                      NaN               NaN
# 2                NaN                      NaN               NaN
# 3  Product Category   When Was Error Detected  Error Type - PPU
# 4                NaN                      NaN               NaN
#
#            Unnamed: 8      Unnamed: 9         Unnamed: 10  \
# 0                 NaN             NaN                 NaN
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0           Unnamed: 1           Unnamed: 2  \
# 0         NaN                  NaN         Error Record
# 1         NaN                  NaN  2022-01-01 00:00:00
# 2         NaN                  NaN                  NaN
# 3         NaN                 Date      Production Area
# 4         NaN                  NaN                  NaN
# 5         NaN  2022-01-04 00:00:00            Zone 5 PN
# 6         NaN  2022-01-04 00:00:00            Zone 5 PN
# 7         NaN  2022-01-04 00:00:00            Zone 5 PN
# 8         NaN  2022-01-04 00:00:00            Zone 5 PN
# 9         NaN  2022-01-04 00:00:00            Zone 5 PN
#
#                   Unnamed: 3 Unnamed: 4                        Unnamed: 5  \
# 0                        NaN        NaN                               NaN
# 1                        NaN        NaN                               NaN
# 2                        NaN        NaN                               NaN
# ...

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.shape
# Out:
# (152, 16)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Unnamed: 0
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
df.to_csv("data/error_csv_clean.csv", index=False)

# %%
df = pd.read_csv("data/error_csv_clean.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Unnamed: 1           Unnamed: 2       Unnamed: 3 Unnamed: 4  \
# 0         NaN        NaN         Error Record              NaN        NaN
# 1         NaN        NaN  2022-01-01 00:00:00              NaN        NaN
# 2         NaN        NaN                  NaN              NaN        NaN
# 3         NaN       Date      Production Area  Licensed Status    Product
# 4         NaN        NaN                  NaN              NaN        NaN
#
#           Unnamed: 5               Unnamed: 6        Unnamed: 7  \
# 0                NaN                      NaN               NaN
# 1                NaN                      NaN               NaN
# 2                NaN                      NaN               NaN
# 3  Product Category   When Was Error Detected  Error Type - PPU
# 4                NaN                      NaN               NaN
#
#            Unnamed: 8      Unnamed: 9         Unnamed: 10  \
# 0                 NaN             NaN                 NaN
# ...
