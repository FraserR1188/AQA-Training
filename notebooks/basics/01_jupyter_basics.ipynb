# %% [markdown]
# # Jupyter Notebook Basics
#
# This notebook covers the fundamentals of working with Jupyter notebooks and Python basics.

# %% [markdown]
# ## 1. Markdown Cells
#
# This is a markdown cell. You can use it for:
# - Documentation
# - Explanations
# - **Formatting** text with *markdown*
# - Creating lists and tables
#
# ### Code Examples
# You can also show code snippets in markdown:
# ```python
# print('Hello, World!')
# ```

# %% [markdown]
# ## 2. Code Cells
#
# Below are executable code cells. Run them to see the output.

# %%
# Basic Python operations
print("Hello from Jupyter!")
print(f"The sum of 5 + 3 is: {5 + 3}")

# %%
# Working with variables
name = "Data Scientist"
years = 5
print(f"I want to be a {name} in {years} years")

# %% [markdown]
# ## 3. Lists and Loops

# %%
# Working with lists
numbers = [1, 2, 3, 4, 5]
print(f"Original list: {numbers}")

# List comprehension
squared = [x**2 for x in numbers]
print(f"Squared values: {squared}")

# %%
# For loop example
fruits = ['apple', 'banana', 'cherry']
for fruit in fruits:
    print(f"I like {fruit}")

# %% [markdown]
# ## 4. Functions

# %%
# Define a simple function
def greet(name):
    return f"Hello, {name}!"

# Call the function
message = greet("Learner")
print(message)

# %%
# Function with multiple parameters
def calculate_area(length, width):
    return length * width

area = calculate_area(10, 5)
print(f"The area is: {area}")

# %% [markdown]
# ## 5. Dictionaries

# %%
# Working with dictionaries
person = {
    'name': 'Alice',
    'age': 30,
    'city': 'London'
}

print(f"Name: {person['name']}")
print(f"Age: {person['age']}")
print(f"City: {person['city']}")

# %%
# Iterating through dictionary
for key, value in person.items():
    print(f"{key}: {value}")

# %% [markdown]
# ## 6. Practice Exercise
#
# Try modifying the cells above or create your own cells below to practice!

# %%
# Your practice code here
